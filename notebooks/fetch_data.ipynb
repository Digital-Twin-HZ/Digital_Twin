# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/Totaal influentdebiet RWZI Ede 2021 minuut gegevens.csv',delimiter=';')
df

# %%
df1 = pd.read_parquet('../Data/zuurstofA_EDE_B121069901_K600.MTW.parquet')
df1
